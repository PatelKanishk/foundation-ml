# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter( df.year , df["per capita income (US$)"], color='red', marker='*')

# %%
new_df=df.drop("per capita income (US$)",axis="columns")
new_df.head(5)
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
y = df["per capita income (US$)"]
y.head(5)
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
model=linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(new_df,y)
# Out:
# LinearRegression()

# %%
model.predict([[2020]])
# Out:
# c:\Users\patel\OneDrive\Desktop\foundation-ml\env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
plt.scatter(new_df,y)
plt.plot(new_df, model.predict(new_df), color='red')
